# %%
import json 
import requests

# %%
params = {"api_key" : "nDeG1JOlpWmoDjspehWbn9NWvPc3cmRCdVT6OczN",
          "school.state" : "MN",
          "school.name": "Century College"
        }
base_url = "https://api.data.gov/ed/collegescorecard/v1/schools.json?"
response = requests.get(base_url, params=params).json()
data = json.dumps(response, indent= 4, sort_keys= True)
print (data)
# Out:
# {
#     "metadata": {
#         "page": 0,
#         "per_page": 20,
#         "total": 1
#     },
#     "results": [
#         {
#             "fed_sch_cd": "010546",
#             "id": 175315,
#             "latest": {
#                 "academics": {
#                     "program": {
#                         "assoc": {
#                             "agriculture": 1,
#                             "architecture": 0,
#                             "biological": 1,
#                             "business_marketing": 1,
#                             "communication": 0,
#                             "communications_technology": 1,
#                             "computer": 1,
#                             "construction": 1,
#                             "education": 1,
#                             "engineering": 1,
#                             "engineering_technology": 1,
#                             "english": 0,
#                             "ethnic_cultural_gender": 0,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 results = data["results"][0]["id"]
#
# TypeError: string indices must be integers
